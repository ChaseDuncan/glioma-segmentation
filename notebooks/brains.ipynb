# %%
from nilearn import plotting
import nibabel as nib
import gzip

# %%
test_file = "/home/cddunca2/data/miccai-brats-2018-data-training/HGG/" \
    +"Brats18_TCIA08_469_1/Brats18_TCIA08_469_1_flair.nii.gz"
img = nib.load(test_file)
print(img.get_fdata().shape)
plotting.plot_img(img)
# Out:
# (240, 240, 155)
